# %%
import pandas as pd
import scanpy as sc

# Load the dropout matrix (rows: genes, columns: cells) and immediately transpose
counts = pd.read_csv('..\..\data/S10000_O/noise_dropout_0.2.csv', index_col=0).T

# Now counts has rows=cells, cols=genes, just like Scanpy expects
adata = sc.AnnData(counts)

# Load integer-indexed labels
labels = pd.read_csv(
    '..\..\data/S10000_O/symsim_labels_2000genes_10000cells_complex.csv',
    index_col=0
)

adata.obs.index = adata.obs.index.str.lstrip('X').astype(int)

adata.obs['cell_class'] = labels.reindex(adata.obs.index)['x'].astype(str)

# %%
#SANITY CHECKS
print("adata shape:", adata.shape)
print(adata.obs['cell_class'].value_counts(dropna=False))
print(adata)
# Out:
# adata shape: (10000, 2000)
# cell_class
# 1    1250
# 2    1250
# 3    1250
# 4    1250
# 5    1250
# 6    1250
# 7    1250
# 8    1250
# Name: count, dtype: int64
# AnnData object with n_obs × n_vars = 10000 × 2000
#     obs: 'cell_class'

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='euclidean')
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Euclidean - Dropout: 0.2")

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='manhattan')
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Manhattan - Dropout: 0.2")

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='minkowski', metric_kwds={'p': 0.5})
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Minkowski p = 0.5 - Dropout: 0.2")

# %%
import pandas as pd
import scanpy as sc

# Load the dropout matrix (rows: genes, columns: cells) and immediately transpose
counts = pd.read_csv('..\..\data/S10000_O/noise_dropout_0.8.csv', index_col=0).T

# Now counts has rows=cells, cols=genes, just like Scanpy expects
adata = sc.AnnData(counts)

# Load integer-indexed labels
labels = pd.read_csv(
    '..\..\data/S10000_O/symsim_labels_2000genes_10000cells_complex.csv',
    index_col=0
)

adata.obs.index = adata.obs.index.str.lstrip('X').astype(int)

adata.obs['cell_class'] = labels.reindex(adata.obs.index)['x'].astype(str)

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='euclidean')
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Euclidean - Dropout: 0.8")

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='manhattan')
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Manhattan - Dropout: 0.8")

# %%
sc.pp.neighbors(adata, n_neighbors=15, use_rep='X', metric='minkowski', metric_kwds={'p': 0.5})
sc.tl.umap(adata, random_state=42)
sc.pl.umap(adata, color="cell_class", size=30, title="S10000_O UMAP - Minkowski p = 0.5 - Dropout: 0.8")
